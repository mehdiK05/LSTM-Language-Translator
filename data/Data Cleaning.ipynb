# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.5.0-py3-none-any.whl (491 kB)
#      -------------------------------------- 491.2/491.2 kB 3.4 MB/s eta 0:00:00
# Collecting pyarrow>=15.0.0
#   Downloading pyarrow-19.0.1-cp39-cp39-win_amd64.whl (25.5 MB)
#      ---------------------------------------- 25.5/25.5 MB 9.9 MB/s eta 0:00:00
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from datasets) (0.3.4)
# Collecting requests>=2.32.2
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ---------------------------------------- 64.9/64.9 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas in c:\users\lenovo\anaconda3\lib\site-packages (from datasets) (1.4.4)
# Collecting fsspec[http]<=2024.12.0,>=2023.1.0
#   Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
#      -------------------------------------- 183.9/183.9 kB 1.8 MB/s eta 0:00:00
# Collecting multiprocess<0.70.17
#   Downloading multiprocess-0.70.16-py39-none-any.whl (133 kB)
#      -------------------------------------- 133.4/133.4 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in c:\users\lenovo\anaconda3\lib\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\lenovo\anaconda3\lib\site-packages (from datasets) (6.0)
# Collecting xxhash
#   Downloading xxhash-3.5.0-cp39-cp39-win_amd64.whl (30 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\lenovo\anaconda3\lib\site-packages (from datasets) (1.21.5)
# Requirement already satisfied: packaging in c:\users\lenovo\anaconda3\lib\site-packages (from datasets) (21.3)
# Collecting aiohttp
#   Downloading aiohttp-3.11.16-cp39-cp39-win_amd64.whl (442 kB)
#      -------------------------------------- 442.4/442.4 kB 9.4 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.24.0
#   Downloading huggingface_hub-0.30.2-py3-none-any.whl (481 kB)
#      ------------------------------------- 481.4/481.4 kB 10.0 MB/s eta 0:00:00
# Collecting tqdm>=4.66.3
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.5/78.5 kB ? eta 0:00:00
# Collecting yarl<2.0,>=1.17.0
#   Downloading yarl-1.19.0-cp39-cp39-win_amd64.whl (93 kB)
#      ---------------------------------------- 93.2/93.2 kB ? eta 0:00:00
# Collecting aiohappyeyeballs>=2.3.0
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.5.0-cp39-cp39-win_amd64.whl (51 kB)
#      ---------------------------------------- 51.8/51.8 kB ? eta 0:00:00
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.4.3-cp39-cp39-win_amd64.whl (38 kB)
# Collecting propcache>=0.2.0
#   Downloading propcache-0.3.1-cp39-cp39-win_amd64.whl (45 kB)
#      ---------------------------------------- 45.7/45.7 kB ? eta 0:00:00
# Collecting async-timeout<6.0,>=4.0
#   Downloading async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp->datasets) (21.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\lenovo\anaconda3\lib\site-packages (from huggingface-hub>=0.24.0->datasets) (4.3.0)
# Collecting dill<0.3.9,>=0.3.0
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      -------------------------------------- 116.3/116.3 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\lenovo\anaconda3\lib\site-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (2022.9.14)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (3.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (2.0.4)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas->datasets) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, tqdm, requests, pyarrow, propcache, multidict, fsspec, frozenlist, dill, async-timeout, aiohappyeyeballs, yarl, multiprocess, huggingface-hub, aiosignal, aiohttp, datasets
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.64.1
#     Uninstalling tqdm-4.64.1:
#       Successfully uninstalled tqdm-4.64.1
#   Attempting uninstall: requests
#     Found existing installation: requests 2.28.1
#     Uninstalling requests-2.28.1:
#       Successfully uninstalled requests-2.28.1
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2022.7.1
#     Uninstalling fsspec-2022.7.1:
#       Successfully uninstalled fsspec-2022.7.1
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.4
#     Uninstalling dill-0.3.4:
#       Successfully uninstalled dill-0.3.4
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.11.16 aiosignal-1.3.2 async-timeout-5.0.1 datasets-3.5.0 dill-0.3.8 frozenlist-1.5.0 fsspec-2024.12.0 huggingface-hub-0.30.2 multidict-6.4.3 multiprocess-0.70.16 propcache-0.3.1 pyarrow-19.0.1 requests-2.32.3 tqdm-4.67.1 xxhash-3.5.0 yarl-1.19.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# anaconda-project 0.11.1 requires ruamel-yaml, which is not installed.
# conda-repo-cli 1.0.20 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.20 requires nbformat==5.4.0, but you have nbformat 5.5.0 which is incompatible.
# conda-repo-cli 1.0.20 requires requests==2.28.1, but you have requests 2.32.3 which is incompatible.

# %%
from datasets import load_dataset
import pandas as pd
from huggingface_hub import login
login()

# Login using e.g. `huggingface-cli login` to access this dataset
ds = load_dataset("atlasia/Atlaset")

df = ds["train"].to_pandas()  # Convert the "train" split to pandas DataFrame
df
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…
# README.md:   0%|          | 0.00/7.61k [00:00<?, ?B/s]
# c:\Users\Lenovo\anaconda3\lib\site-packages\huggingface_hub\file_download.py:144: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Lenovo\.cache\huggingface\hub\datasets--atlasia--Atlaset. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ---------------------------------------------------------------------------
# DatasetNotFoundError                      Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24860\661584549.py in <module>
#       5
#       6 # Login using e.g. `huggingface-cli login` to access this dataset
# ----> 7 ds = load_dataset("atlasia/Atlaset")
#       8
#       9 df = ds["train"].to_pandas()  # Convert the "train" split to pandas DataFrame
#
# c:\Users\Lenovo\anaconda3\lib\site-packages\datasets\load.py in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2060
#    2061     # Create a dataset builder
# -> 2062     builder_instance = load_dataset_builder(
#    2063         path=path,
#    2064         name=name,
#
# c:\Users\Lenovo\anaconda3\lib\site-packages\datasets\load.py in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, storage_options, trust_remote_code, _require_default_config_name, **config_kwargs)
#    1780         download_config = download_config.copy() if download_config else DownloadConfig()
#    1781         download_config.storage_options.update(storage_options)
# -> 1782     dataset_module = dataset_module_factory(
#    1783         path,
#    1784         revision=revision,
#
# c:\Users\Lenovo\anaconda3\lib\site-packages\datasets\load.py in dataset_module_factory(path, revision, download_config, download_mode, dynamic_modules_path, data_dir, data_files, cache_dir, trust_remote_code, _require_default_config_name, _require_custom_configs, **download_kwargs)
#    1650                     raise ConnectionError(f"Couldn't reach the Hugging Face Hub for dataset '{path}': {e1}") from None
#    1651                 if isinstance(e1, (DataFilesNotFoundError, DatasetNotFoundError, EmptyDatasetError)):
# -> 1652                     raise e1 from None
#    1653                 if isinstance(e1, FileNotFoundError):
#    1654                     if trust_remote_code:
#
# c:\Users\Lenovo\anaconda3\lib\site-packages\datasets\load.py in dataset_module_factory(path, revision, download_config, download_mode, dynamic_modules_path, data_dir, data_files, cache_dir, trust_remote_code, _require_default_config_name, _require_custom_configs, **download_kwargs)
#    1634                 elif e.response.status_code == 403:
#    1635                     message += f" Visit the dataset page at https://huggingface.co/datasets/{path} to ask for access."
# -> 1636                 raise DatasetNotFoundError(message) from e
#    1637             except RevisionNotFoundError as e:
#    1638                 raise DatasetNotFoundError(
#
# DatasetNotFoundError: Dataset 'atlasia/Atlaset' is a gated dataset on the Hub. You must be authenticated to access it.

# %% [markdown]
# #Visualisation of the sources

# %%
all_tails = []

for source in unique_sources:
    tail_df = df[df["dataset_source"] == source].tail(1)  # Get the tail for each source
    all_tails.append(tail_df)
final_df = pd.concat(all_tails)
final_df
# Out:
#                                dataset_source  \
# 173526           medmac01/moroccan_history_qa
# 2669                        learnmoroccan.com
# 3097                              loecsen.com
# 139877                            NQ-Open-AYA
# 159005                           common-crawl
# 159420                              auto-math
# 159772                               stanford
# 160018                       translation-rows
# 160158                                wikihow
# 163367         atlasia/darija_english/stories
# 174318  SoftAge-AI/sft-conversational_dataset
# 204751              aboutaleb/moroccantourism
# 242497                                flan_v2
# 336927                                    cot
# 354584                                 oasst1
# 356143                                   lima
# 392354                            gpt4_alpaca
# 517842                               sharegpt
# 555419                               wizardlm
#
#                                                      text  \
# 173526  قصر دار المخزن كان بناه السلطان العلوي محمد بن...
# 2669                                                عياقة
# 3097                                               عروبية
# 139877                                                عدو
# 159005  ﺍﻟﺴﻼﻡ ﻋﻠﻴﻜﻢ ﺣﺒﻴﺒﺎﺗﻲ < br > ﻗﻨﺎﺗﻲ ﺩﻳﺎﻝ ﺍﻟﻄﺒﺦ ﺩﺧ...
# 159420  العنوان: فهم التكرار البسيط مع مثال علبة الشوك...
# 159772  **1.2 أهمية دراسة تاريخ لأفارقة لأمريكان ؤ\n\n...
# 160018  العنوان: كيفاش تتغلب على الإحساس بأنك عبء\n: م...
# 160158  العنوان: كيفاش تولي مدرس خصوصي أو معلم شخصي\n\...
# 163367  ...شاف فيها و قال اشنو بغيتي تاخدي تحرجات الاء...
# 174318  باش تبعد الفيران من دارك خاصك تجمع بين مجموعة ...
# 204751  يمكنك الاتصال بشافعي فواياج، وكالة سفر فمراكش،...
# 242497  إلا مشا بوب على الجيهة اللي طولها 120 فوت، غاد...
# 336927             واش رجب طيب أردوغان ما كيعرفش البوريك؟
# 354584  \nفالموسم اللول د دراغون بول ما كاينش فيغيتا، ...
# 356143  "closes over" يعني كيشير "لشي متغير محلي [مثلا...
# 392354  لكل عدد صحيح، بادي من القيمة ديال 0 وأقل من ال...
# 517842  الأدوية المضادة للفيروسات ماشي غير كتستعمل للف...
# 555419  ضمان أمن البيانات فبيئة متعددة الأجهزة مع الال...
#
#                                                  metadata  token_count  \
# 173526  {'english': 'The Dar al-Makhzan palace was bui...           26
# 2669    {'english': 'Bragging', 'darija_Latn': '', 'da...            2
# 3097    {'english': 'The countryside', 'darija_Latn': ...            3
# 139877  {'english': 'enemy', 'darija_Latn': '', 'datas...            2
# 159005  {'english': 'Hello my loves
# Enter my cooking c...          201
# 159420  {'english': ' Title: Understanding Simple Recu...          782
# 159772  {'english': ' **1.2 The Importance of Studying...           53
# 160018  {'english': ' Title: When My Love for Birdwatc...          591
# 160158  {'english': ' Title: How to Become a Tutor or ...         1566
# 163367  {'english': 'He looked at her and asked, "What...          227
# 174318  {'english': 'Keeping rats away from your home ...          315
# 204751  {'english': 'You can contact CHAFAI VOYAGES, a...           30
# 242497  {'english': 'If Bob goes along the side that's...           95
# 336927  {'english': 'Would Recep Tayyip Erdoğan be unf...           11
# 354584  {'english': 'Dragoi bolaren aurreneko denboral...           64
# 356143  {'english': '"closes over" i.e. refers "to a l...          139
# 392354  {'english': 'For each integer, starting at the...           21
# 517842  {'english': 'Antiviral drugs are not only used...          239
# 555419  {'english': 'Ensuring data security in a multi...          752
#
#         word_count                                             darija  \
# 173526          22  قصر دار المخزن كان بناه السلطان العلوي محمد بن...
# 2669             1                                              عياقة
# 3097             1                                             عروبية
# 139877           1                                                عدو
# 159005          20  ﺍﻟﺴﻼﻡ ﻋﻠﻴﻜﻢ ﺣﺒﻴﺒﺎﺗﻲ < br > ﻗﻨﺎﺗﻲ ﺩﻳﺎﻝ ﺍﻟﻄﺒﺦ ﺩﺧ...
# 159420         430  العنوان: فهم التكرار البسيط مع مثال علبة الشوك...
# 159772          33  **1.2 أهمية دراسة تاريخ لأفارقة لأمريكان ؤ\n\n...
# 160018         355  العنوان: كيفاش تتغلب على الإحساس بأنك عبء\n: م...
# 160158         958  العنوان: كيفاش تولي مدرس خصوصي أو معلم شخصي\n\...
# 163367         123  ...شاف فيها و قال اشنو بغيتي تاخدي تحرجات الاء...
# 174318         175  باش تبعد الفيران من دارك خاصك تجمع بين مجموعة ...
# 204751          14  يمكنك الاتصال بشافعي فواياج، وكالة سفر فمراكش،...
# 242497          65  إلا مشا بوب على الجيهة اللي طولها 120 فوت، غاد...
# 336927           7             واش رجب طيب أردوغان ما كيعرفش البوريك؟
# 354584          34  \nفالموسم اللول د دراغون بول ما كاينش فيغيتا، ...
# 356143          80  "closes over" يعني كيشير "لشي متغير محلي [مثلا...
# 392354          16  لكل عدد صحيح، بادي من القيمة ديال 0 وأقل من ال...
# 517842         154  الأدوية المضادة للفيروسات ماشي غير كتستعمل للف...
# 555419         538  ضمان أمن البيانات فبيئة متعددة الأجهزة مع الال...
#
#                                                   english
# 173526  The Dar al-Makhzan palace was built by the Ala...
# 2669                                             Bragging
# 3097                                      The countryside
# 139877                                              enemy
# 159005  Hello my loves\nEnter my cooking channel, may ...
# 159420  Title: Understanding Simple Recursion with the...
# 159772  **1.2 The Importance of Studying African Ameri...
# 160018  Title: When My Love for Birdwatching Led Me to...
# 160158  Title: How to Become a Tutor or Personal Teach...
# 163367  He looked at her and asked, "What do you want ...
# 174318  Keeping rats away from your home requires a co...
# 204751  You can contact CHAFAI VOYAGES, a travel agenc...
# 242497  If Bob goes along the side that's 120 feet lon...
# 336927  Would Recep Tayyip Erdoğan be unfamiliar with ...
# 354584  Dragoi bolaren aurreneko denboraldian ez da Ve...
# 356143  "closes over" i.e. refers "to a local variable...
# 392354  For each integer, starting at the value of 0 a...
# 517842  Antiviral drugs are not only used for life-thr...
# 555419  Ensuring data security in a multi-device envir...

# %% [markdown]
# #Removing rows for other tasks than machine translation

# %%
all_tails = []

for i in range(20):
    if unique_sources[i] != 'bourbouh/moroccan-darija-youtube-subtitles':
      tail_df = df[df["dataset_source"] == unique_sources[i]]
      all_tails.append(tail_df)

final_df = pd.concat(all_tails)
final_df
# Out:
#                       dataset_source  \
# 0       medmac01/moroccan_history_qa
# 1       medmac01/moroccan_history_qa
# 2       medmac01/moroccan_history_qa
# 3       medmac01/moroccan_history_qa
# 4       medmac01/moroccan_history_qa
# ...                              ...
# 555415                      wizardlm
# 555416                      wizardlm
# 555417                      wizardlm
# 555418                      wizardlm
# 555419                      wizardlm
#
#                                                      text  \
# 0       التقريب أكثر من نص مصاريف المخزن كانت كتمشي لب...
# 1         ماهي عواقب مصاريف المخزن على الاقتصاد المغربي؟
# 2       نفقات المخزن أدت إلى تدهور الاقتصاد المغربي، ح...
# 3       في تسعينيات القرن التاسع عشر، طالبت الإدارة وا...
# 4       ما كانو الأسباب الرئيسية اللي دفعو فرنسا باش ت...
# ...                                                   ...
# 555415  باش نضمنو أن كل راكب عندو رحلة، وما يبقى حتى ب...
# 555416  عاود كتابة الجملة التالية باش تكون أقصر وزيد ط...
# 555417  "جيب استعلام SQL كيجمع عدد الدراري اللي كيديرو...
# 555418  كيفاش واحد يقدر يضمن أن البيانات ديالو آمنة فب...
# 555419  ضمان أمن البيانات فبيئة متعددة الأجهزة مع الال...
#
#                                                  metadata  token_count  \
# 0       {'english': "More than half of the Makhzen's e...           97
# 1       {'english': "What were the consequences of the...            9
# 2       {'english': "The Makhzen's expenditures led to...           48
# 3       {'english': 'In the 1890s, the French administ...           57
# 4       {'english': 'What were the main reasons behind...           24
# ...                                                   ...          ...
# 555415  {'english': 'To ensure that each passenger has...          269
# 555416  {'english': 'Rewrite the following sentence to...           57
# 555417  {'english': '"Generate a SQL query grouping th...           30
# 555418  {'english': 'How can someone ensure their data...           94
# 555419  {'english': "Ensuring data security in a multi...          752
#
#         word_count
# 0               75
# 1                7
# 2               42
# 3               47
# 4               16
# ...            ...
# 555415         166
# 555416          35
# 555417          16
# 555418          70
# 555419         538
#
# [555172 rows x 5 columns]

# %% [markdown]
# #visualizing the format of metadata column

# %%
final_df['metadata'][10]
# Out:
# "{'english': 'What was the outcome of the Algeciras Conference in 1906?', 'darija_Latn': '', 'dataset_source': 'medmac01/moroccan_history_qa', 'id': 'None', 'role': 'None', 'darija_tokens': '19', 'subtopic': '', 'topic': '', 'annotator_dialect': ''}"

# %% [markdown]
# #extracting english string data

# %%
import ast
final_df["metadata"] = final_df["metadata"].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
final_df["darija"] = final_df["text"]
final_df["english"] = final_df["metadata"].apply(lambda x: x.get("english", "").strip() if isinstance(x, dict) else "")
ready_df = final_df[["darija", "english"]]
ready_df
# Out:
#                                                    darija  \
# 0       التقريب أكثر من نص مصاريف المخزن كانت كتمشي لب...
# 1         ماهي عواقب مصاريف المخزن على الاقتصاد المغربي؟
# 2       نفقات المخزن أدت إلى تدهور الاقتصاد المغربي، ح...
# 3       في تسعينيات القرن التاسع عشر، طالبت الإدارة وا...
# 4       ما كانو الأسباب الرئيسية اللي دفعو فرنسا باش ت...
# ...                                                   ...
# 555415  باش نضمنو أن كل راكب عندو رحلة، وما يبقى حتى ب...
# 555416  عاود كتابة الجملة التالية باش تكون أقصر وزيد ط...
# 555417  "جيب استعلام SQL كيجمع عدد الدراري اللي كيديرو...
# 555418  كيفاش واحد يقدر يضمن أن البيانات ديالو آمنة فب...
# 555419  ضمان أمن البيانات فبيئة متعددة الأجهزة مع الال...
#
#                                                   english
# 0       More than half of the Makhzen's expenditures w...
# 1       What were the consequences of the Makhzen's ex...
# 2       The Makhzen's expenditures led to a deteriorat...
# 3       In the 1890s, the French administration and mi...
# 4       What were the main reasons behind the French a...
# ...                                                   ...
# 555415  To ensure that each passenger has a ride, and ...
# 555416  Rewrite the following sentence to make it more...
# 555417  "Generate a SQL query grouping the number of n...
# 555418  How can someone ensure their data is secure in...
# 555419  Ensuring data security in a multi-device envir...
#
# [555172 rows x 2 columns]

# %%
readytest_df.to_csv('ready_df.csv', index=True)
